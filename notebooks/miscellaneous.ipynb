# %%
import helpers.gates as gates
import helpers.common as common

# %% [markdown]
# ## Gates Used

# %%
gates.sum.draw("mpl")

# %%
gates.transversal_sum.draw("mpl")

# %%
gates.carry.draw("mpl")

# %%
gates.reverse_carry.draw("mpl")

# %%
gates.shor_setup.draw("mpl")

# %%
gates.shor_teardown.draw("mpl")

# %%
common.plot_old_simulation("cxdvqk63ej4g008fw26g", "result")
